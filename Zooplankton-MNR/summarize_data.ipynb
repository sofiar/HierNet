# %%
import pandas as pd
from hierclassifier.samples_setup import ImageDataset, merge_classes

# %% [markdown]
# ### Get data - Zooplankton

# %%
DataPath = '/data/Hier-Zooplankton'


RESOLUTION = 65
SEED = 6565

# %% [markdown]
# ### Crate ImageDataset

# %%
SELECTED_LIST = [
    '149um>',
    'Asplanchna',
    'Bosminidae',
    'Brachionidae',
    'Bubbles',
    'Bythotrephes',
    'Calanoid',
    'Ceriodaphnia',
    'Chydoridae',
    'Cladocera',
    'Conochilus',
    'Copepoda',
    'Cyclopoid',
    'Daphnia',
    'Debris',
    'Duplicates',
    'Eubosmina',
    'Exoskeleton',
    'Fiber_Hairlike',
    'Fiber_Squiggly',
    'Harpacticoid',
    'Holopedium',
    'Kellicottia',
    'Keratella',
    'Leptodora',
    'MultiClass',
    'Nauplius_Copepod',
    'Partial_Copepod',
    'Partial_Daphnia',
    'Partial_Leptodora',
    'Partial_Other',
    'Phytoplankton',
    'Plant_Matter',
    'Ploima',
    'Polyarthra',
    'Rotifer',
    'Sididae',
    'Trichocerca',
    'Unknown',
    'Unknown_Small'        
    ]

dataset_selected = ImageDataset(
    data_directory = DataPath,
    class_names = SELECTED_LIST,
    max_class_size = 15000,
    image_resolution = 64,
    image_transforms = None,
    format_file = '.tif',
    seed = SEED
    )

# %% [markdown]
# ### Print details

# %%
data_details = dataset_selected.get_dataset_details()
dataset_selected.print_dataset_details()
# Out:
# Total Dataset Size: 68807
# Class Name: 149um> | Class Label: 0 | Count: 12073 | Prop: 0.18
# Class Name: Asplanchna | Class Label: 1 | Count: 162 | Prop: 0.00
# Class Name: Bosminidae | Class Label: 2 | Count: 3035 | Prop: 0.04
# Class Name: Brachionidae | Class Label: 3 | Count: 202 | Prop: 0.00
# Class Name: Bubbles | Class Label: 4 | Count: 57 | Prop: 0.00
# Class Name: Bythotrephes | Class Label: 5 | Count: 1 | Prop: 0.00
# Class Name: Calanoid | Class Label: 6 | Count: 519 | Prop: 0.01
# Class Name: Ceriodaphnia | Class Label: 7 | Count: 89 | Prop: 0.00
# Class Name: Chydoridae | Class Label: 8 | Count: 7 | Prop: 0.00
# Class Name: Cladocera | Class Label: 9 | Count: 932 | Prop: 0.01
# Class Name: Conochilus | Class Label: 10 | Count: 34 | Prop: 0.00
# Class Name: Copepoda | Class Label: 11 | Count: 593 | Prop: 0.01
# Class Name: Cyclopoid | Class Label: 12 | Count: 1478 | Prop: 0.02
# Class Name: Daphnia | Class Label: 13 | Count: 3038 | Prop: 0.04
# Class Name: Debris | Class Label: 14 | Count: 15000 | Prop: 0.22
# Class Name: Duplicates | Class Label: 15 | Count: 7 | Prop: 0.00
# Class Name: Eubosmina | Class Label: 16 | Count: 301 | Prop: 0.00
# Class Name: Exoskeleton | Class Label: 17 | Count: 2516 | Prop: 0.04
# Class Name: Fiber_Hairlike | Class Label: 18 | Count: 5288 | Prop: 0.08
# Class Name: Fiber_Squiggly | Class Label: 19 | Count: 6455 | Prop: 0.09
# Class Name: Harpacticoid | Class Label: 20 | Count: 43 | Prop: 0.00
# Class Name: Holopedium | Class Label: 21 | Count: 508 | Prop: 0.01
# Class Name: Kellicottia | Class Label: 22 | Count: 876 | Prop: 0.01
# Class Name: Keratella | Class Label: 23 | Count: 168 | Prop: 0.00
# Class Name: Leptodora | Class Label: 24 | Count: 48 | Prop: 0.00
# Class Name: MultiClass | Class Label: 25 | Count: 133 | Prop: 0.00
# Class Name: Nauplius_Copepod | Class Label: 26 | Count: 6050 | Prop: 0.09
# Class Name: Partial_Copepod | Class Label: 27 | Count: 38 | Prop: 0.00
# Class Name: Partial_Daphnia | Class Label: 28 | Count: 56 | Prop: 0.00
# Class Name: Partial_Leptodora | Class Label: 29 | Count: 1 | Prop: 0.00
# Class Name: Partial_Other | Class Label: 30 | Count: 28 | Prop: 0.00
# Class Name: Phytoplankton | Class Label: 31 | Count: 10 | Prop: 0.00
# Class Name: Plant_Matter | Class Label: 32 | Count: 2046 | Prop: 0.03
# Class Name: Ploima | Class Label: 33 | Count: 3 | Prop: 0.00
# Class Name: Polyarthra | Class Label: 34 | Count: 34 | Prop: 0.00
# Class Name: Rotifer | Class Label: 35 | Count: 3132 | Prop: 0.05
# Class Name: Sididae | Class Label: 36 | Count: 171 | Prop: 0.00
# Class Name: Trichocerca | Class Label: 37 | Count: 40 | Prop: 0.00
# Class Name: Unknown | Class Label: 38 | Count: 890 | Prop: 0.01
# Class Name: Unknown_Small | Class Label: 39 | Count: 2745 | Prop: 0.04

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt 
df = pd.DataFrame(data_details)

ax = df.plot(x='Class',y='Counts', kind='bar',legend = False, figsize=(12, 5))
for p in ax.patches:
    ax.annotate(
        str(int(p.get_height())),                
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha="center", va="bottom"                
    )

plt.ylabel('Counts')
plt.title('Class Distribution')
plt.show()
